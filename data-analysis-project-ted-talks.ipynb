# %% [markdown]
# # This Python 3 environment comes with many helpful analytics libraries installed
# # It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# # For example, here's several helpful packages to load
#
# import numpy as np # linear algebra
# import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
#
# # Input data files are available in the read-only "../input/" directory
# # For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory
#
# import os
# for dirname, _, filenames in os.walk('/kaggle/input'):
#     for filename in filenames:
#         print(os.path.join(dirname, filename))
#
# # You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All"
# # You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# referance : https://towardsai.net/p/l/data-analysis-project-with-pandasstep-by-step-guide-ted-talks-data

# %%
#import libraries 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#datasets
ted_main_data_path = '/kaggle/input/ted-talks/ted_main.csv'
ted_main_data = pd.read_csv(ted_main_data_path)

# %%
#The Shape of the Data
#print(ted_main_data)
print("Shape of the data frame:")
print(ted_main_data.shape)
# Out:
# Shape of the data frame:
# (2550, 17)

# %%
#Pandas Data Types
print(ted_main_data.dtypes)
# Out:
# comments               int64
# description           object
# duration               int64
# event                 object
# film_date              int64
# languages              int64
# main_speaker          object
# name                  object
# num_speaker            int64
# published_date         int64
# ratings               object
# related_talks         object
# speaker_occupation    object
# tags                  object
# title                 object
# url                   object
# views                  int64
# dtype: object

# %%
#Information About the Data
ted_main_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2550 entries, 0 to 2549
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   comments            2550 non-null   int64
#  1   description         2550 non-null   object
#  2   duration            2550 non-null   int64
#  3   event               2550 non-null   object
#  4   film_date           2550 non-null   int64
#  5   languages           2550 non-null   int64
#  6   main_speaker        2550 non-null   object
#  7   name                2550 non-null   object
#  8   num_speaker         2550 non-null   int64
#  9   published_date      2550 non-null   int64
#  10  ratings             2550 non-null   object
#  11  related_talks       2550 non-null   object
#  12  speaker_occupation  2544 non-null   object
#  13  tags                2550 non-null   object
#  14  title               2550 non-null   object
# ...

# %%
#Missing Values
ted_main_data.isnull().sum()
ted_main_data.isnull().values.sum()
# Out:
# 6

# %%
#Descriptive Statistics about the Data
ted_main_data.describe()
# Out:
#           comments     duration     film_date    languages  num_speaker  \
# count  2550.000000  2550.000000  2.550000e+03  2550.000000  2550.000000
# mean    191.562353   826.510196  1.321928e+09    27.326275     1.028235
# std     282.315223   374.009138  1.197391e+08     9.563452     0.207705
# min       2.000000   135.000000  7.464960e+07     0.000000     1.000000
# 25%      63.000000   577.000000  1.257466e+09    23.000000     1.000000
# 50%     118.000000   848.000000  1.333238e+09    28.000000     1.000000
# 75%     221.750000  1046.750000  1.412964e+09    33.000000     1.000000
# max    6404.000000  5256.000000  1.503792e+09    72.000000     5.000000
#
#        published_date         views
# count    2.550000e+03  2.550000e+03
# mean     1.343525e+09  1.698297e+06
# std      9.464009e+07  2.498479e+06
# min      1.151367e+09  5.044300e+04
# 25%      1.268463e+09  7.557928e+05
# 50%      1.340935e+09  1.124524e+06
# 75%      1.423432e+09  1.700760e+06
# ...

# %% [markdown]
# **Which talks provoke the most online discussion?**

# %%
#print(ted_main_data.corr())
# plotting correlation heatmap
dataplot = sns.heatmap(ted_main_data.corr(), annot=True)
  
# displaying heatmap
plt.show()
#number of views correlates well with language and comments

# %%
plt.hist(ted_main_data[['comments', 'languages']])
plt.show()
